# %%
import random

joueur1 = []  # joueur1 du jeux
joueur2 = []
print("joueur1 : ", joueur1)
jdc1 = []


#----------------------------------------------------------------------------
#-------------------------Fonction reste de cartes ?-------------------------
#----------------------------------------------------------------------------


def Cb_reste_il_de_cartes():

    if(len(joueur1)+len(joueur2) != len(jdc1)):
        #print("Nombre de cartes restantes : ",  len(joueur1)+len(joueur2)+len(tg1)+len(tg2))
        print("Nombre de cartes restantes : ",  len(joueur1)+len(joueur2))
        print("Oups")

#----------------------------------------------------------------------------
#-------------------------Fonction choix du nombre de cartes-----------------
#----------------------------------------------------------------------------

def Choix_du_nbre(): 
    nbCartes=0
    
    while (nbCartes!=32 and nbCartes!=54):
        nbCartes = int(input("Quel nombre de cartes voulez-vous ? (32 ou 54) "))  
    return nbCartes
    

#----------------------------------------------------------------------------
#-------------------------Fonction céation du jeu----------------------------
#----------------------------------------------------------------------------

def Création_du_jeux(nbcartes):
    _jdc1=[]
    if nbcartes==32:
        for i in range(7, 15):  # definition jeux de 32 cartes
            _jdc1.append((i, 'coeur'))  # definition cartes de coeur
            _jdc1.append((i, 'pique'))  # definition cartes de pique
            _jdc1.append((i, 'trefle'))  # definition cartes de trèfles
            _jdc1.append((i, 'carreau'))  # definition cartes de carreau
            # print(jdc1[i-7])
    
    elif nbcartes==54:  
        for i in range(1, 15):  # definition jeux de 32 cartes
            _jdc1.append((i, 'coeur'))  # definition cartes de coeur
            _jdc1.append((i, 'pique'))  # definition cartes de pique
            _jdc1.append((i, 'trefle'))  # definition cartes de trèfles
            _jdc1.append((i, 'carreau'))  # definition cartes de carreau
    
    random.shuffle(_jdc1)  # melange des cartes
    return _jdc1
    
#----------------------------------------------------------------------------
#-------------------------Fonction distribution des cartes-------------------
#----------------------------------------------------------------------------
def Distrib_cartes():
    print(len(jdc1))
    for d in range(Nbcartes):
        if d % 2 == 0:
            joueur1.append(jdc1[d])
        else:
            joueur2.append(jdc1[d])
    print("joueur2 : ", joueur2)
    print("joueur1 : ", joueur1)


#----------------------------------------------------------------------------32
#------------------Fonction bataille et comparasion des cartes---------------
#----------------------------------------------------------------------------

def Exe_jeu():
    global nbParties
    while joueur1 != [] and joueur2 != []:
        nbParties +=1 
        print("nombre de partie : ", nbParties)
        print("joueur1 : ", len(joueur1))
        print("joueur2 : ", len(joueur2))

        tg1 = []
        tg2 = []
        tg1.append(joueur1[0])
        tg2.append(joueur2[0])
        del joueur1[0]
        del joueur2[0]

        if tg1[0][0] == tg2[0][0]:  # égalité
            print("égalité")
            # si un joueur à moins de 3 cartes alors le vainqueur est celui
            # qui a le plus de cartes

            # tant qu'il y a bataille :
            while tg1[len(tg1)-1][0] == tg2[len(tg2)-1][0]:
                # bataille
                print("Bataille")
                if len(joueur1) < 3:
                    for cartes_restantes in joueur1:
                        joueur2.append(cartes_restantes)
                    del joueur1[:]
                    for i in range(len(tg1)):
                        joueur2.append(tg1[i])
                        joueur2.append(tg2[i])
                    del tg2[:]
                    del tg1[:] 
                    print("fin de partie j1 est à sec.")   
                    break    
                    #del joueur1
                    
                elif len(joueur2) < 3:
                    for cartes_restantes in joueur2:
                            joueur1.append(cartes_restantes)
                    del joueur2[:]        
                    for i in range(len(tg1)):
                        joueur1.append(tg1[i])
                        joueur1.append(tg2[i])
                        #del joueur2
                    del tg2[:]
                    del tg1[:]
                    print("fin de partie j2 est à sec.")   

                    break

                else:
                    for i in range(0, 2):
                        tg1.append(joueur1[0])
                        tg2.append(joueur2[0])
                        del joueur1[0]
                        del joueur2[0]

                # comparaison de la dernière carte posée
                if tg1[len(tg1)-1][0] > tg2[len(tg2)-1][0]:
                    for i in range(len(tg1)):
                        joueur1.append(tg1[i])
                        joueur1.append(tg2[i])
                    
                elif tg1[len(tg1)-1][0] < tg2[len(tg2)-1][0]:
                    for i in range(len(tg1)):
                        joueur2.append(tg1[i])
                        joueur2.append(tg2[i])
                
                #Cb_reste_il_de_cartes()

        elif tg1[len(tg1)-1][0] > tg2[len(tg2)-1][0]:  # joueur gagnant 1
            joueur1.append(tg2[0])
            joueur1.append(tg1[0])
            print("Gagnant joueur1.")

        elif tg1[0][0] < tg2[0][0]:  # joueur gagnant 2
            joueur2.append(tg1[0])
            joueur2.append(tg2[0])
            print("Gagnant joueur2.")

        #print("joueur2 : ",joueur2)
        #print("joueur1 : ",joueur1)
        del tg1[:]
        del tg2[:]

#----------------------------------------------------------------------------
#-------------------------Fonction podium------------------------------------
#----------------------------------------------------------------------------
def podium(nbrj1,nbrj2,nbparties):
    if (nbrj1 > nbrj2) :
        print("c'est le joueur 1 qui a gagné la partie.")
    else:
        print("c'est le joueur 2 qui a gagné la partie.")
    print("A gagné(e) la partie après : ",nbparties," nombre de parties.")
# Out:
# joueur1 :  []

# %%
#----------------------------------------------------------------------------
#-------------------------Debut du programme---------------------------------
#----------------------------------------------------------------------------

nbParties = 0
Nbcartes=Choix_du_nbre()
jdc1 = Création_du_jeux(Nbcartes)
print(jdc1)

Distrib_cartes()

Exe_jeu()

podium(len(joueur1) , len(joueur2) ,nbParties)
# Out:
# [(13, 'pique'), (13, 'carreau'), (10, 'pique'), (14, 'coeur'), (8, 'trefle'), (11, 'pique'), (14, 'trefle'), (14, 'pique'), (11, 'carreau'), (9, 'coeur'), (8, 'pique'), (7, 'coeur'), (7, 'pique'), (7, 'carreau'), (8, 'coeur'), (10, 'carreau'), (12, 'pique'), (10, 'coeur'), (8, 'carreau'), (12, 'carreau'), (9, 'pique'), (13, 'trefle'), (7, 'trefle'), (14, 'carreau'), (9, 'carreau'), (10, 'trefle'), (13, 'coeur'), (12, 'coeur'), (11, 'trefle'), (11, 'coeur'), (9, 'trefle'), (12, 'trefle')]
# 32
# joueur2 :  [(13, 'carreau'), (14, 'coeur'), (11, 'pique'), (14, 'pique'), (9, 'coeur'), (7, 'coeur'), (7, 'carreau'), (10, 'carreau'), (10, 'coeur'), (12, 'carreau'), (13, 'trefle'), (14, 'carreau'), (10, 'trefle'), (12, 'coeur'), (11, 'coeur'), (12, 'trefle')]
# joueur1 :  [(13, 'pique'), (10, 'pique'), (8, 'trefle'), (14, 'trefle'), (11, 'carreau'), (8, 'pique'), (7, 'pique'), (8, 'coeur'), (12, 'pique'), (8, 'carreau'), (9, 'pique'), (7, 'trefle'), (9, 'carreau'), (13, 'coeur'), (11, 'trefle'), (9, 'trefle')]
# nombre de partie :  1
# joueur1 :  16
# joueur2 :  16
# égalité
# Bataille
# nombre de partie :  2
# joueur1 :  13
# joueur2 :  19
# égalité
# Bataille
# nombre de partie :  3
# joueur1 :  16
# joueur2 :  16
# égalité
# Bataille
# nombre de partie :  4
# joueur1 :  19
# joueur2 :  13
# Gagnant joueur2.
# nombre de partie :  5
# joueur1 :  18
# joueur2 :  14
# Gagnant joueur2.
# nombre de partie :  6
# joueur1 :  17
# joueur2 :  15
# Gagnant joueur2.
# nombre de partie :  7
# joueur1 :  16
# joueur2 :  16
# Gagnant joueur2.
# nombre de partie :  8
# joueur1 :  15
# joueur2 :  17
# Gagnant joueur1.
# nombre de partie :  9
# joueur1 :  16
# joueur2 :  16
# égalité
# Bataille
# nombre de partie :  10
# joueur1 :  19
# joueur2 :  13
# Gagnant joueur1.
# nombre de partie :  11
# joueur1 :  20
# joueur2 :  12
# Gagnant joueur1.
# nombre de partie :  12
# joueur1 :  21
# joueur2 :  11
# Gagnant joueur2.
# nombre de partie :  13
# joueur1 :  20
# joueur2 :  12
# égalité
# Bataille
# nombre de partie :  14
# joueur1 :  17
# joueur2 :  15
# Gagnant joueur2.
# nombre de partie :  15
# joueur1 :  16
# joueur2 :  16
# Gagnant joueur2.
# nombre de partie :  16
# joueur1 :  15
# joueur2 :  17
# Gagnant joueur2.
# nombre de partie :  17
# joueur1 :  14
# joueur2 :  18
# Gagnant joueur1.
# nombre de partie :  18
# joueur1 :  15
# joueur2 :  17
# Gagnant joueur2.
# nombre de partie :  19
# joueur1 :  14
# joueur2 :  18
# Gagnant joueur1.
# nombre de partie :  20
# joueur1 :  15
# joueur2 :  17
# Gagnant joueur1.
# nombre de partie :  21
# joueur1 :  16
# joueur2 :  16
# Gagnant joueur1.
# nombre de partie :  22
# joueur1 :  17
# joueur2 :  15
# Gagnant joueur2.
# nombre de partie :  23
# joueur1 :  16
# joueur2 :  16
# Gagnant joueur1.
# nombre de partie :  24
# joueur1 :  17
# joueur2 :  15
# Gagnant joueur1.
# nombre de partie :  25
# joueur1 :  18
# joueur2 :  14
# Gagnant joueur1.
# nombre de partie :  26
# joueur1 :  19
# joueur2 :  13
# Gagnant joueur1.
# nombre de partie :  27
# joueur1 :  20
# joueur2 :  12
# Gagnant joueur1.
# nombre de partie :  28
# joueur1 :  21
# joueur2 :  11
# Gagnant joueur1.
# nombre de partie :  29
# joueur1 :  22
# joueur2 :  10
# Gagnant joueur1.
# nombre de partie :  30
# joueur1 :  23
# joueur2 :  9
# Gagnant joueur2.
# nombre de partie :  31
# joueur1 :  22
# joueur2 :  10
# Gagnant joueur2.
# nombre de partie :  32
# joueur1 :  21
# joueur2 :  11
# Gagnant joueur1.
# nombre de partie :  33
# joueur1 :  22
# joueur2 :  10
# Gagnant joueur2.
# nombre de partie :  34
# joueur1 :  21
# joueur2 :  11
# Gagnant joueur2.
# nombre de partie :  35
# joueur1 :  20
# joueur2 :  12
# égalité
# Bataille
# nombre de partie :  36
# joueur1 :  17
# joueur2 :  15
# Gagnant joueur2.
# nombre de partie :  37
# joueur1 :  16
# joueur2 :  16
# Gagnant joueur2.
# nombre de partie :  38
# joueur1 :  15
# joueur2 :  17
# Gagnant joueur2.
# nombre de partie :  39
# joueur1 :  14
# joueur2 :  18
# Gagnant joueur1.
# nombre de partie :  40
# joueur1 :  15
# joueur2 :  17
# Gagnant joueur1.
# nombre de partie :  41
# joueur1 :  16
# joueur2 :  16
# Gagnant joueur2.
# nombre de partie :  42
# joueur1 :  15
# joueur2 :  17
# Gagnant joueur1.
# nombre de partie :  43
# joueur1 :  16
# joueur2 :  16
# Gagnant joueur2.
# nombre de partie :  44
# joueur1 :  15
# joueur2 :  17
# égalité
# Bataille
# nombre de partie :  45
# joueur1 :  18
# joueur2 :  14
# Gagnant joueur2.
# nombre de partie :  46
# joueur1 :  17
# joueur2 :  15
# égalité
# Bataille
# nombre de partie :  47
# joueur1 :  14
# joueur2 :  18
# Gagnant joueur2.
# nombre de partie :  48
# joueur1 :  13
# joueur2 :  19
# Gagnant joueur2.
# nombre de partie :  49
# joueur1 :  12
# joueur2 :  20
# Gagnant joueur2.
# nombre de partie :  50
# joueur1 :  11
# joueur2 :  21
# Gagnant joueur2.
# nombre de partie :  51
# joueur1 :  10
# joueur2 :  22
# Gagnant joueur2.
# nombre de partie :  52
# joueur1 :  9
# joueur2 :  23
# égalité
# Bataille
# nombre de partie :  53
# joueur1 :  12
# joueur2 :  20
# Gagnant joueur1.
# nombre de partie :  54
# joueur1 :  13
# joueur2 :  19
# Gagnant joueur1.
# nombre de partie :  55
# joueur1 :  14
# joueur2 :  18
# Gagnant joueur2.
# nombre de partie :  56
# joueur1 :  13
# joueur2 :  19
# Gagnant joueur2.
# nombre de partie :  57
# joueur1 :  12
# joueur2 :  20
# Gagnant joueur2.
# nombre de partie :  58
# joueur1 :  11
# joueur2 :  21
# Gagnant joueur2.
# nombre de partie :  59
# joueur1 :  10
# joueur2 :  22
# Gagnant joueur1.
# nombre de partie :  60
# joueur1 :  11
# joueur2 :  21
# Gagnant joueur1.
# nombre de partie :  61
# joueur1 :  12
# joueur2 :  20
# égalité
# Bataille
# nombre de partie :  62
# joueur1 :  15
# joueur2 :  17
# Gagnant joueur2.
# nombre de partie :  63
# joueur1 :  14
# joueur2 :  18
# Gagnant joueur2.
# nombre de partie :  64
# joueur1 :  13
# joueur2 :  19
# Gagnant joueur2.
# nombre de partie :  65
# joueur1 :  12
# joueur2 :  20
# Gagnant joueur1.
# nombre de partie :  66
# joueur1 :  13
# joueur2 :  19
# Gagnant joueur1.
# nombre de partie :  67
# joueur1 :  14
# joueur2 :  18
# Gagnant joueur2.
# nombre de partie :  68
# joueur1 :  13
# joueur2 :  19
# Gagnant joueur1.
# nombre de partie :  69
# joueur1 :  14
# joueur2 :  18
# Gagnant joueur1.
# nombre de partie :  70
# joueur1 :  15
# joueur2 :  17
# Gagnant joueur1.
# nombre de partie :  71
# joueur1 :  16
# joueur2 :  16
# Gagnant joueur1.
# nombre de partie :  72
# joueur1 :  17
# joueur2 :  15
# Gagnant joueur1.
# nombre de partie :  73
# joueur1 :  18
# joueur2 :  14
# Gagnant joueur2.
# nombre de partie :  74
# joueur1 :  17
# joueur2 :  15
# Gagnant joueur2.
# nombre de partie :  75
# joueur1 :  16
# joueur2 :  16
# Gagnant joueur1.
# nombre de partie :  76
# joueur1 :  17
# joueur2 :  15
# Gagnant joueur2.
# nombre de partie :  77
# joueur1 :  16
# joueur2 :  16
# Gagnant joueur2.
# nombre de partie :  78
# joueur1 :  15
# joueur2 :  17
# Gagnant joueur2.
# nombre de partie :  79
# joueur1 :  14
# joueur2 :  18
# Gagnant joueur2.
# nombre de partie :  80
# joueur1 :  13
# joueur2 :  19
# Gagnant joueur1.
# nombre de partie :  81
# joueur1 :  14
# joueur2 :  18
# égalité
# Bataille
# nombre de partie :  82
# joueur1 :  11
# joueur2 :  21
# Gagnant joueur2.
# nombre de partie :  83
# joueur1 :  10
# joueur2 :  22
# Gagnant joueur1.
# nombre de partie :  84
# joueur1 :  11
# joueur2 :  21
# Gagnant joueur1.
# nombre de partie :  85
# joueur1 :  12
# joueur2 :  20
# égalité
# Bataille
# nombre de partie :  86
# joueur1 :  9
# joueur2 :  23
# Gagnant joueur2.
# nombre de partie :  87
# joueur1 :  8
# joueur2 :  24
# Gagnant joueur1.
# nombre de partie :  88
# joueur1 :  9
# joueur2 :  23
# égalité
# Bataille
# nombre de partie :  89
# joueur1 :  12
# joueur2 :  20
# Gagnant joueur2.
# nombre de partie :  90
# joueur1 :  11
# joueur2 :  21
# Gagnant joueur2.
# nombre de partie :  91
# joueur1 :  10
# joueur2 :  22
# égalité
# Bataille
# nombre de partie :  92
# joueur1 :  7
# joueur2 :  25
# Gagnant joueur1.
# nombre de partie :  93
# joueur1 :  8
# joueur2 :  24
# Gagnant joueur1.
# nombre de partie :  94
# joueur1 :  9
# joueur2 :  23
# Gagnant joueur1.
# nombre de partie :  95
# joueur1 :  10
# joueur2 :  22
# Gagnant joueur1.
# nombre de partie :  96
# joueur1 :  11
# joueur2 :  21
# Gagnant joueur2.
# nombre de partie :  97
# joueur1 :  10
# joueur2 :  22
# Gagnant joueur1.
# nombre de partie :  98
# joueur1 :  11
# joueur2 :  21
# Gagnant joueur2.
# nombre de partie :  99
# joueur1 :  10
# joueur2 :  22
# Gagnant joueur1.
# nombre de partie :  100
# joueur1 :  11
# joueur2 :  21
# Gagnant joueur1.
# nombre de partie :  101
# joueur1 :  12
# joueur2 :  20
# Gagnant joueur1.
# nombre de partie :  102
# joueur1 :  13
# joueur2 :  19
# Gagnant joueur1.
# nombre de partie :  103
# joueur1 :  14
# joueur2 :  18
# Gagnant joueur1.
# nombre de partie :  104
# joueur1 :  15
# joueur2 :  17
# Gagnant joueur1.
# nombre de partie :  105
# joueur1 :  16
# joueur2 :  16
# Gagnant joueur2.
# nombre de partie :  106
# joueur1 :  15
# joueur2 :  17
# Gagnant joueur2.
# nombre de partie :  107
# joueur1 :  14
# joueur2 :  18
# Gagnant joueur1.
# nombre de partie :  108
# joueur1 :  15
# joueur2 :  17
# Gagnant joueur1.
# nombre de partie :  109
# joueur1 :  16
# joueur2 :  16
# Gagnant joueur2.
# nombre de partie :  110
# joueur1 :  15
# joueur2 :  17
# Gagnant joueur2.
# nombre de partie :  111
# joueur1 :  14
# joueur2 :  18
# Gagnant joueur2.
# nombre de partie :  112
# joueur1 :  13
# joueur2 :  19
# Gagnant joueur1.
# nombre de partie :  113
# joueur1 :  14
# joueur2 :  18
# Gagnant joueur2.
# nombre de partie :  114
# joueur1 :  13
# joueur2 :  19
# Gagnant joueur1.
# nombre de partie :  115
# joueur1 :  14
# joueur2 :  18
# Gagnant joueur1.
# nombre de partie :  116
# joueur1 :  15
# joueur2 :  17
# Gagnant joueur1.
# nombre de partie :  117
# joueur1 :  16
# joueur2 :  16
# Gagnant joueur1.
# nombre de partie :  118
# joueur1 :  17
# joueur2 :  15
# Gagnant joueur2.
# nombre de partie :  119
# joueur1 :  16
# joueur2 :  16
# Gagnant joueur1.
# nombre de partie :  120
# joueur1 :  17
# joueur2 :  15
# égalité
# Bataille
# nombre de partie :  121
# joueur1 :  14
# joueur2 :  18
# Gagnant joueur1.
# nombre de partie :  122
# joueur1 :  15
# joueur2 :  17
# égalité
# Bataille
# nombre de partie :  123
# joueur1 :  18
# joueur2 :  14
# Gagnant joueur2.
# nombre de partie :  124
# joueur1 :  17
# joueur2 :  15
# Gagnant joueur2.
# nombre de partie :  125
# joueur1 :  16
# joueur2 :  16
# Gagnant joueur1.
# nombre de partie :  126
# joueur1 :  17
# joueur2 :  15
# Gagnant joueur1.
# nombre de partie :  127
# joueur1 :  18
# joueur2 :  14
# Gagnant joueur1.
# nombre de partie :  128
# joueur1 :  19
# joueur2 :  13
# Gagnant joueur1.
# nombre de partie :  129
# joueur1 :  20
# joueur2 :  12
# Gagnant joueur2.
# nombre de partie :  130
# joueur1 :  19
# joueur2 :  13
# Gagnant joueur2.
# nombre de partie :  131
# joueur1 :  18
# joueur2 :  14
# Gagnant joueur2.
# nombre de partie :  132
# joueur1 :  17
# joueur2 :  15
# Gagnant joueur2.
# nombre de partie :  133
# joueur1 :  16
# joueur2 :  16
# Gagnant joueur1.
# nombre de partie :  134
# joueur1 :  17
# joueur2 :  15
# Gagnant joueur1.
# nombre de partie :  135
# joueur1 :  18
# joueur2 :  14
# Gagnant joueur1.
# nombre de partie :  136
# joueur1 :  19
# joueur2 :  13
# Gagnant joueur1.
# nombre de partie :  137
# joueur1 :  20
# joueur2 :  12
# Gagnant joueur2.
# nombre de partie :  138
# joueur1 :  19
# joueur2 :  13
# Gagnant joueur2.
# nombre de partie :  139
# joueur1 :  18
# joueur2 :  14
# Gagnant joueur1.
# nombre de partie :  140
# joueur1 :  19
# joueur2 :  13
# Gagnant joueur2.
# nombre de partie :  141
# joueur1 :  18
# joueur2 :  14
# égalité
# Bataille
# Bataille
# Bataille
# nombre de partie :  142
# joueur1 :  25
# joueur2 :  7
# égalité
# Bataille
# nombre de partie :  143
# joueur1 :  28
# joueur2 :  4
# Gagnant joueur1.
# nombre de partie :  144
# joueur1 :  29
# joueur2 :  3
# Gagnant joueur1.
# nombre de partie :  145
# joueur1 :  30
# joueur2 :  2
# égalité
# Bataille
# fin de partie j2 est à sec.
# c'est le joueur 1 qui a gagné la partie.
# A gagné(e) la partie après :  145  nombre de parties.
